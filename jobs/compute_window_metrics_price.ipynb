# %%
# STEP 0: Imports (run once)
from pyspark.sql import SparkSession, functions as F
import os

from trading.config.storage import STORAGE
from trading.data.lake_layout import curated_ohlcv_prefix, window_metrics_prefix
from trading.features.windows import add_returns, add_time_buckets
from trading.features.metrics_price import PRICE_METRICS
from trading.features.metric_utils import metrics_set_fingerprint
from trading.features.snapshots import compute_input_snapshot_id
from trading.runs.run_logging import log_window_metric_run
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# No module named 'trading'
# Traceback (most recent call last):
# ModuleNotFoundError: No module named 'trading'

# %%
# STEP 1: Manually set parameters for this experiment

entity = "price"
asset_class = "crypto"
timeframe = "1d"

exchange = "binance"
asset = "ethusdt"

start_dt = "2024-01-01"
end_dt   = "2024-03-01"

window = "1 week"          # same as args.window in the script
code_version = "notebook-test"  # or a git hash if you want
