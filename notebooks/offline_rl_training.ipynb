# %%
print("Container file present:", os.path.exists("/.dockerenv"))

# %%
import pyarrow.parquet as pq
import numpy as np

# %%
df = pq.read_table("s3://trading-kbarczak/data/curated/trades_agg_roll_1s/asset_class=cryptocurrency/asset=ethusdt/dt=2020-04-03/").to_pandas()
# X = df[cols].to_numpy().astype(np.float32)
